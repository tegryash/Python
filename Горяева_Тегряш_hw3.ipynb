# %%
class Ore:
    def __init__(self, id, composition, weight):
        self.id = id
        self.composition = composition
        self.weight = weight

    def get_info(self):
        return "Ore: ID=" + str(self.id) + " Composition=" + self.composition +" Weight="+ str(self.weight)


class CyanideSolution:
    def __init__(self, concentration, purity):
        self.concentration = concentration
        self.purity = purity

    def get_info(self):
        return "Cyanide Solution: Concentration=" +str(self.concentration) +" g/l Purity=" + str(self.purity) + "%"


class Filter:
    def __init__(self, filter_id, filter_type, wear_level, filter_producer):
        self.filter_id = filter_id
        self.filter_type = filter_type
        self.wear_level = wear_level
        self.filter_producer=filter_producer

    def filter_batch(self):
        if self.wear_level > 80:
            print("Filter needs to be replaced")

    def replace_filter(self):
        self.wear_level = 0
        print("Filter replaced")


class Crusher:
    def __init__(self, fraction_size):
        self.fraction_size=fraction_size

    def crush(self, ore):
        print("Crushing ore: " + ore.get_info())
        return Batch(ore.weight)


class OreBatch:
    def __init__(self, weight):
        self.weight = weight
        self.contamination_level = 0

    def update_contamination(self, level):
        self.contamination_level = level
        print("Contamination level updated to " + str(self.contamination_level) + "%")

    def get_info(self):
        return "Batch: Weight=" + str(self.weight) + " kg, Contamination=" + str(self.contamination_level) + "%"


class Catalyst:
    def __init__(self, concentration):
        self.concentration = concentration

    def get_info(self):
        return "Catalyst: Concentration=" + str(self.concentration) + " g/l"


class Cyanidation:
    def __init__(self, batch, solution, catalyst):
        self.batch = batch
        self.solution = solution
        self.catalyst = catalyst

    def process_batch(self):
        pass
